# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Credit_card1.csv")
df
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
df.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
df.tail()
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type  Birthday_count  Employed_days  \
# 1543               Married  House / apartment        -11957.0          -2182
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
df.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# ...

# %%
df.drop_duplicates()
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
df.dropna()
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 8     5010864      M         Y             Y         1       450000.0
# 9     5010868      M         Y             Y         1       450000.0
# 10    5010869      M         Y             Y         1       450000.0
# 11    5018498      F         Y             Y         0        90000.0
# 13    5018503      F         Y             Y         0        90000.0
# ...       ...    ...       ...           ...       ...            ...
# 1540  5024049      F         Y             Y         1       144000.0
# 1542  5118268      M         Y             N         1       360000.0
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
#
#                Type_Income                      EDUCATION  \
# 8     Commercial associate  Secondary / secondary special
# ...

# %%
df.nunique()
# Out:
# Ind_ID             1548
# GENDER                2
# Car_Owner             2
# Propert_Owner         2
# CHILDREN              6
# Annual_income       115
# Type_Income           4
# EDUCATION             5
# Marital_status        5
# Housing_type          6
# Birthday_count     1270
# Employed_days       956
# Mobile_phone          1
# Work_Phone            2
# Phone                 2
# EMAIL_ID              2
# Type_Occupation      18
# Family_Members        7
# Table2.label          2
# dtype: int64

# %%
sns.pairplot(df)

# %%
correlation=df.corr()
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)

# %%
# Checking Non-Numerical Columns
df.columns[(df.dtypes =='object').values].tolist()
# Out:
# ['GENDER',
#  'Car_Owner',
#  'Propert_Owner',
#  'Type_Income',
#  'EDUCATION',
#  'Marital_status',
#  'Housing_type',
#  'Type_Occupation']

# %%
# Checking Numerical Columns
df.columns[(df.dtypes !='object').values].tolist()
# Out:
# ['Ind_ID',
#  'CHILDREN',
#  'Annual_income',
#  'Birthday_count',
#  'Employed_days',
#  'Mobile_phone',
#  'Work_Phone',
#  'Phone',
#  'EMAIL_ID',
#  'Family_Members',
#  'Table2.label']

# %%
# Checking unique values from Categorical values
for i in df.columns[(df.dtypes =='object').values].tolist():
    print(i,'\n')
    print(df[i].value_counts())
    print('-----------------------------------------------')
# Out:
# GENDER
#
# F    973
# M    568
# Name: GENDER, dtype: int64
# -----------------------------------------------
# Car_Owner
#
# N    924
# Y    624
# Name: Car_Owner, dtype: int64
# -----------------------------------------------
# Propert_Owner
#
# Y    1010
# N     538
# Name: Propert_Owner, dtype: int64
# -----------------------------------------------
# Type_Income
#
# Working                 798
# Commercial associate    365
# Pensioner               269
# State servant           116
# Name: Type_Income, dtype: int64
# -----------------------------------------------
# EDUCATION
#
# Secondary / secondary special    1031
# Higher education                  426
# Incomplete higher                  68
# Lower secondary                    21
# Academic degree                     2
# Name: EDUCATION, dtype: int64
# -----------------------------------------------
# Marital_status
#
# Married                 1049
# Single / not married     227
# Civil marriage           101
# ...

# %%
df['CHILDREN'].value_counts()
# Out:
# 0     1091
# 1      305
# 2      134
# 3       16
# 4        1
# 14       1
# Name: CHILDREN, dtype: int64

# %%
# Checking Min , Max values from 'DAYS_BIRTH' column
print('Min DAYS_BIRTH :', df['Birthday_count'].min(),'\nMax DAYS_BIRTH :', df['Birthday_count'].max())
# Out:
# Min DAYS_BIRTH : -24946.0
# Max DAYS_BIRTH : -7705.0

# %%
# Converting 'Birthday_count' values from Day to Years
df['Birthday_count'] = round(df['Birthday_count']/-365,0)
df.rename(columns={'Birthday_count':'AGE_YEARS'}, inplace=True)

# %%
df['Employed_days'] = round(df['Employed_days']/-365,0)
df.rename(columns={'Employed_days':'Employed_years'},inplace=True)

# %%
df['Mobile_phone'].value_counts()
# Out:
# 1    1548
# Name: Mobile_phone, dtype: int64

# %%
df['Work_Phone'].value_counts()
# Out:
# 0    1226
# 1     322
# Name: Work_Phone, dtype: int64

# %%
df['Phone'].value_counts()
# Out:
# 0    1069
# 1     479
# Name: Phone, dtype: int64

# %%
df['EMAIL_ID'].value_counts()
# Out:
# 0    1405
# 1     143
# Name: EMAIL_ID, dtype: int64

# %%
df['Family_Members'].value_counts()
# Out:
# 2     802
# 1     334
# 3     268
# 4     127
# 5      15
# 6       1
# 15      1
# Name: Family_Members, dtype: int64

# %%
df.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'AGE_YEARS', 'Employed_years', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members',
#        'Table2.label'],
#       dtype='object')

# %%
sns.boxplot(df['CHILDREN'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['Annual_income'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['AGE_YEARS'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['Employed_years'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['Family_Members'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Removing Outliners

# %%
high_bound = df['CHILDREN'].quantile(0.999)
print('high_bound :', high_bound)
low_bound = df['CHILDREN'].quantile(0.001)
print('low_bound :', low_bound)
# Out:
# high_bound : 3.453000000000202
# low_bound : 0.0

# %%
df = df[(df['CHILDREN']>=low_bound) & (df['CHILDREN']<=high_bound)]

# %%
high_bound = df['Annual_income'].quantile(0.999)
print('high_bound :', high_bound)
low_bound = df['Annual_income'].quantile(0.001)
print('low_bound :', low_bound)
# Out:
# high_bound : 1222650.0000000442
# low_bound : 36939.6

# %%
df = df[(df['Annual_income']>=low_bound) & (df['Annual_income']<=high_bound)]

# %%
high_bound = df['AGE_YEARS'].quantile(0.999)
print('high_bound :', high_bound)
low_bound = df['AGE_YEARS'].quantile(0.001)
print('low_bound :', low_bound)
# Out:
# high_bound : 67.50400000000013
# low_bound : 22.496

# %%
df = df[(df['AGE_YEARS']>=low_bound) & (df['AGE_YEARS']<=high_bound)]

# %%
high_bound = df['Employed_years'].quantile(0.999)
print('high_bound :', high_bound)
low_bound = df['Employed_years'].quantile(0.001)
print('low_bound :', low_bound)
# Out:
# high_bound : 37.508000000000266
# low_bound : -1001.0

# %%
df = df[(df['Employed_years']>=low_bound) & (df['Employed_years']<=high_bound)]

# %%
high_bound = df['Family_Members'].quantile(0.999)
print('high_bound :', high_bound)
low_bound = df['Family_Members'].quantile(0.001)
print('low_bound :', low_bound)
# Out:
# high_bound : 5.0
# low_bound : 1.0

# %%
df = df[(df['Family_Members']>=low_bound) & (df['Family_Members']<=high_bound)]

# %%
df.isnull().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income        0
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# AGE_YEARS            0
# Employed_years       0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    469
# Family_Members       0
# Table2.label         0
# dtype: int64

# %%
df['Table2.label'].value_counts()
# Out:
# 0    1327
# 1     164
# Name: Table2.label, dtype: int64

# %%
correlation=df.corr()
sns.heatmap(correlation, xticklabels= correlation.columns, yticklabels= correlation.columns, annot= True)

# %%
# This graph shows that, majority of application are submitted by Female's
plt.pie(df['GENDER'].value_counts(), labels=['Female', 'Male'], autopct='%1.2f%%')
plt.title('% of Applications submitted based on Gender')
plt.show()

# %%
plt.pie(df[df['Table2.label']==0]['GENDER'].value_counts(), labels=['Female', 'Male'], autopct='%1.2f%%')
plt.title('% of Applications Approved based on Gender')
plt.show()

# %%
# This graph shows that, majority of applicatant's dont own a car
plt.pie(df['Car_Owner'].value_counts(), labels=['No', 'Yes'], autopct='%1.2f%%')
plt.title('% of Applications submitted based on owning a Car')
plt.show()

# %%
plt.pie(df['Propert_Owner'].value_counts(), labels=['No', 'Yes'], autopct='%1.2f%%')
plt.title('% of Applications submitted based on owning Property')
plt.show()

# %%
# This graph shows that, majority of applicatant's don't have any children
plt.figure(figsize = (8,8))
plt.pie(df['CHILDREN'].value_counts(), labels=df['CHILDREN'].value_counts().index, autopct='%1.2f%%')
plt.title('% of Applications submitted based on Children count')
plt.legend()
plt.show()

# %%
# This graph shows that, majority of applicatant's income lies between 1 to 3 lakh
plt.hist(df['Annual_income'], bins=20)
plt.xlabel('Total Annual Income')
plt.title('Histogram')
plt.show()

# %%
# This graph shows that, majority of applicatant's are working professional
plt.figure(figsize = (8,8))
plt.pie(df['Type_Income'].value_counts(), labels=df['Type_Income'].value_counts().index, autopct='%1.2f%%')
plt.title('% of Applications submitted based on Income Type')
plt.legend()
plt.show()

# %%
# This graph shows that, majority of applicatant's completed the Secondary Education
plt.figure(figsize=(8,8))
plt.pie(df['EDUCATION'].value_counts(), labels=df['EDUCATION'].value_counts().index, autopct='%1.2f%%')
plt.title('% of Applications submitted based on Education')
plt.legend()
plt.show()

# %%
#Most of the applicants are married
plt.figure(figsize=(8,8))
plt.pie(df['Marital_status'].value_counts(), labels=df['Marital_status'].value_counts().index, autopct='%1.2f%%')
plt.title('% of Applications submitted based on Marital Status')
plt.legend()
plt.show()

# %% [markdown]
# Feature Selection

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
for col in df:
  if df[col].dtypes == 'object':
    df[col]= le.fit_transform(df[col])

# %%
df.head()
# Out:
#     Ind_ID  GENDER  Car_Owner  Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827       1          1              1         0       180000.0
# 1  5009744       0          1              0         0       315000.0
# 4  5009752       0          1              0         0       315000.0
# 5  5009753       2          1              0         0       315000.0
# 6  5009754       0          1              0         0       315000.0
#
#    Type_Income  EDUCATION  Marital_status  Housing_type  AGE_YEARS  \
# 0            1          1               1             1       51.0
# 1            0          1               1             1       37.0
# 4            0          1               1             1       37.0
# 5            1          1               1             1       37.0
# 6            0          1               1             1       37.0
#
#    Employed_years  Mobile_phone  Work_Phone  Phone  EMAIL_ID  Type_Occupation  \
# ...

# %%
df.corr()
# Out:
#                    Ind_ID    GENDER  Car_Owner  Propert_Owner  CHILDREN  \
# Ind_ID           1.000000  0.019017  -0.053156      -0.056060  0.031596
# GENDER           0.019017  1.000000   0.369330      -0.043891  0.053703
# Car_Owner       -0.053156  0.369330   1.000000       0.001602  0.057685
# Propert_Owner   -0.056060 -0.043891   0.001602       1.000000 -0.021770
# CHILDREN         0.031596  0.053703   0.057685      -0.021770  1.000000
# Annual_income    0.005839  0.264552   0.212351       0.035156  0.080747
# Type_Income      0.032716  0.053650   0.034722      -0.052407  0.061770
# EDUCATION        0.030685 -0.051905  -0.126367      -0.022302 -0.084772
# Marital_status   0.011611 -0.122926  -0.146418      -0.000571 -0.190645
# Housing_type     0.021657  0.082643   0.001862      -0.172729  0.009800
# AGE_YEARS       -0.015760 -0.186440  -0.134784       0.123226 -0.322164
# Employed_years   0.052489  0.171122   0.138880      -0.102703  0.238629
# ...

# %% [markdown]
# MACHINE LEARNING MODEL

# %%
df.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'AGE_YEARS', 'Employed_years', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members',
#        'Table2.label'],
#       dtype='object')

# %%
#X= df.drop(['Ind_ID', 'Table2.label', 'Mobile_phone', 'Work_Phone', 'Phone', 'EMAIL_ID'], axis=1)
#y= df['Table2.label']

# %%
X = df[['GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN','Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status','Housing_type', 'AGE_YEARS', 'Employed_years', 'EMAIL_ID', 'Type_Occupation', 'Family_Members']]

# %%
y= df['Table2.label']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test= train_test_split(X,y,train_size=0.25,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train= sc.fit_transform(X_train)
X_train
# Out:
# array([[-0.76843247, -0.91242113,  0.72860428, ..., -0.34222378,
#         -0.18777363,  0.84426597],
#        [ 1.24464414, -0.91242113, -1.37248713, ..., -0.34222378,
#         -0.18777363, -0.23500187],
#        [-0.76843247, -0.91242113, -1.37248713, ..., -0.34222378,
#          0.47432865,  1.92353381],
#        ...,
#        [-0.76843247, -0.91242113,  0.72860428, ..., -0.34222378,
#         -0.51882477, -0.23500187],
#        [ 1.24464414,  1.09598514,  0.72860428, ..., -0.34222378,
#         -1.18092704, -0.23500187],
#        [ 1.24464414, -0.91242113, -1.37248713, ..., -0.34222378,
#         -0.18777363, -0.23500187]])

# %%
X_test = sc.transform(X_test)
X_test
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 1.73713154,  1.2887623 , -4.25620806, ..., -1.4593409 ,
#         -1.92890808, -2.64716751],
#        [-2.31534591,  1.2887623 ,  0.15837706, ...,  9.19623776,
#         -2.12069908, -3.81198658],
#        [-2.31534591, -2.74493344, -4.25620806, ...,  9.19623776,
#         -1.7645158 , -2.64716751],
#        ...,
#        [ 1.73713154,  1.2887623 ,  0.15837706, ...,  9.19623776,
#         -2.06590165, -1.48234844],
#        [ 1.73713154, -2.74493344, -4.25620806, ..., -1.4593409 ,
#         -1.87411066, -2.64716751],
#        [ 1.73713154,  1.2887623 ,  0.15837706, ...,  9.19623776,
#         -1.87411066, -3.81198658]])

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression(random_state=0)

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_lr= lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, fbeta_score

# %%
confusion_mat = confusion_matrix(y_test, y_lr)
confusion_mat
# Out:
# array([[996,   0],
#        [123,   0]])

# %%
print(accuracy_score(y_test, y_lr))
# Out:
# 0.8900804289544236

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       996
#            1       0.00      0.00      0.00       123
#
#     accuracy                           0.89      1119
#    macro avg       0.45      0.50      0.47      1119
# weighted avg       0.79      0.89      0.84      1119
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred_knn=knn.predict(X_test)

# %%
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.8865058087578195

# %%
confusion_matrix(y_test,y_pred_knn)
# Out:
# array([[991,   5],
#        [122,   1]])

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       996
#            1       0.17      0.01      0.02       123
#
#     accuracy                           0.89      1119
#    macro avg       0.53      0.50      0.48      1119
# weighted avg       0.81      0.89      0.84      1119

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf=GradientBoostingClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gb=clf.predict(X_test)

# %%
accuracy_score(y_test,pred_gb)
# Out:
# 0.8909740840035746

# %%
confusion_matrix(y_test,pred_gb)
# Out:
# array([[994,   2],
#        [120,   3]])

# %%
print(classification_report(y_test,pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       996
#            1       0.60      0.02      0.05       123
#
#     accuracy                           0.89      1119
#    macro avg       0.75      0.51      0.49      1119
# weighted avg       0.86      0.89      0.84      1119

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(max_depth=2)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=2)

# %%
pred_rfc=rfc.predict(X_test)

# %%
accuracy_score(y_test,pred_rfc)
# Out:
# 0.8900804289544236

# %%
confusion_matrix(y_test,pred_rfc)
# Out:
# array([[996,   0],
#        [123,   0]])

# %%
print(classification_report(y_test,pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       996
#            1       0.00      0.00      0.00       123
#
#     accuracy                           0.89      1119
#    macro avg       0.45      0.50      0.47      1119
# weighted avg       0.79      0.89      0.84      1119
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_gnb = gnb.predict(X_test)

# %%
accuracy_score(y_test,y_gnb)
# Out:
# 0.8909740840035746

# %%
confusion_matrix(y_test,y_gnb)
# Out:
# array([[994,   2],
#        [120,   3]])

# %%
print(classification_report(y_test,y_gnb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       996
#            1       0.60      0.02      0.05       123
#
#     accuracy                           0.89      1119
#    macro avg       0.75      0.51      0.49      1119
# weighted avg       0.86      0.89      0.84      1119

# %% [markdown]
# ###CONCLUSION
# #From the above results we can state that Random Forest Classifier and Gausian Bayes are best model to predict Credit card approval based on the accurancy score, precision, F1_Score
